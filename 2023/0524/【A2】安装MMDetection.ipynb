# %% [markdown]
# # 安装MMDetection

# %% [markdown]
# 按照顺序逐行运行本代码，即可安装配置 MMDetection 环境
#
# 推荐代码运行[云GPU环境](https://featurize.cn?s=d7ce99f842414bfcaea5662a97581bd1)：GPU RTX 3060、CUDA v11.2
#
# 作者：同济子豪兄 2023-4-3

# %% [markdown]
# > 提示：以下代码运行时，若长时间运行卡着不动，可重启 kernel 后重新运行一遍

# %% [markdown]
# ## 安装Pytorch

# %%
# 安装Pytorch
#!pip3 install install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %% [markdown]
# ## 用MIM安装MMCV

# %%
# !pip install -U openmim
# !mim install mmcv-full
# !mim install mmengine
# !mim install 'mmcv==2.0.0rc3'
# !mim install "mmdet>=3.0.0rc6"
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: openmim in d:\anaconda3\envs\openmmlab\lib\site-packages (0.3.9)
# Requirement already satisfied: Click in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (2.0.3)
# Requirement already satisfied: pip>=19.3 in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (23.3.1)
# Requirement already satisfied: requests in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in d:\anaconda3\envs\openmmlab\lib\site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in d:\anaconda3\envs\openmmlab\lib\site-packages (from model-index->openmim) (6.0.1)
# Requirement already satisfied: markdown in d:\anaconda3\envs\openmmlab\lib\site-packages (from model-index->openmim) (3.5.1)
# Requirement already satisfied: ordered-set in d:\anaconda3\envs\openmmlab\lib\site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in d:\anaconda3\envs\openmmlab\lib\site-packages (from opendatalab->openmim) (3.19.0)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\openmmlab\lib\site-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in d:\anaconda3\envs\openmmlab\lib\site-packages (from opendatalab->openmim) (0.0.29)
# Requirement already satisfied: pywin32 in d:\anaconda3\envs\openmmlab\lib\site-packages (from opendatalab->openmim) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\envs\openmmlab\lib\site-packages (from requests->openmim) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\openmmlab\lib\site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\openmmlab\lib\site-packages (from requests->openmim) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\envs\openmmlab\lib\site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from pandas->openmim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in d:\anaconda3\envs\openmmlab\lib\site-packages (from pandas->openmim) (1.24.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from rich->openmim) (2.15.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from rich->openmim) (4.7.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\openmmlab\lib\site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\anaconda3\envs\openmmlab\lib\site-packages (from markdown->model-index->openmim) (7.0.0)
# Requirement already satisfied: oss2~=2.17.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: setuptools~=60.2.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\openmmlab\lib\site-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.11.0)
# Requirement already satisfied: crcmod>=1.7 in d:\anaconda3\envs\openmmlab\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in d:\anaconda3\envs\openmmlab\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.14.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in d:\anaconda3\envs\openmmlab\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in d:\anaconda3\envs\openmmlab\lib\site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in d:\anaconda3\envs\openmmlab\lib\site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.21)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.1.0/index.html
# Collecting mmcv-full
#   Using cached https://mirrors.aliyun.com/pypi/packages/12/a3/9e4f4f6e44aa234498d995d98ee60b7f5dbab3148d7b4fbd4097396c928f/mmcv-full-1.7.1.tar.gz (605 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: addict in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: numpy in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (1.24.3)
# Requirement already satisfied: packaging in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (23.1)
# Requirement already satisfied: Pillow in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (10.0.1)
# Requirement already satisfied: pyyaml in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (6.0.1)
# Requirement already satisfied: yapf in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (0.40.2)
# Requirement already satisfied: regex in d:\anaconda3\envs\openmmlab\lib\site-packages (from mmcv-full) (2023.10.3)
# Requirement already satisfied: importlib-metadata>=6.6.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from yapf->mmcv-full) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from yapf->mmcv-full) (3.10.0)
# Requirement already satisfied: tomli>=2.0.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from yapf->mmcv-full) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\openmmlab\lib\site-packages (from importlib-metadata>=6.6.0->yapf->mmcv-full) (3.11.0)
# Building wheels for collected packages: mmcv-full
#   Building wheel for mmcv-full (setup.py): started
#   Building wheel for mmcv-full (setup.py): still running...
#   Building wheel for mmcv-full (setup.py): finished with status 'error'
#   Running setup.py clean for mmcv-full
# Failed to build mmcv-full
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [1612 lines of output]
#   C:\Users\storm\AppData\Local\Temp\pip-install-amzl3oqv\mmcv-full_5360dc4d70e24f00808ab0a4608b0e6e\setup.py:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#     from pkg_resources import DistributionNotFound, get_distribution
#   running bdist_wheel
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\torch\utils\cpp_extension.py:502: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#     warnings.warn(msg.format('we could not find ninja.'))
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-38
#   creating build\lib.win-amd64-cpython-38\mmcv
#   copying mmcv\version.py -> build\lib.win-amd64-cpython-38\mmcv
#   copying mmcv\__init__.py -> build\lib.win-amd64-cpython-38\mmcv
#   creating build\lib.win-amd64-cpython-38\mmcv\arraymisc
#   copying mmcv\arraymisc\quantization.py -> build\lib.win-amd64-cpython-38\mmcv\arraymisc
#   copying mmcv\arraymisc\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\arraymisc
#   creating build\lib.win-amd64-cpython-38\mmcv\cnn
#   copying mmcv\cnn\alexnet.py -> build\lib.win-amd64-cpython-38\mmcv\cnn
#   copying mmcv\cnn\builder.py -> build\lib.win-amd64-cpython-38\mmcv\cnn
#   copying mmcv\cnn\resnet.py -> build\lib.win-amd64-cpython-38\mmcv\cnn
#   copying mmcv\cnn\vgg.py -> build\lib.win-amd64-cpython-38\mmcv\cnn
#   copying mmcv\cnn\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\cnn
#   creating build\lib.win-amd64-cpython-38\mmcv\device
#   copying mmcv\device\scatter_gather.py -> build\lib.win-amd64-cpython-38\mmcv\device
#   copying mmcv\device\utils.py -> build\lib.win-amd64-cpython-38\mmcv\device
#   copying mmcv\device\_functions.py -> build\lib.win-amd64-cpython-38\mmcv\device
#   copying mmcv\device\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\device
#   creating build\lib.win-amd64-cpython-38\mmcv\engine
#   copying mmcv\engine\test.py -> build\lib.win-amd64-cpython-38\mmcv\engine
#   copying mmcv\engine\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\engine
#   creating build\lib.win-amd64-cpython-38\mmcv\fileio
#   copying mmcv\fileio\file_client.py -> build\lib.win-amd64-cpython-38\mmcv\fileio
#   copying mmcv\fileio\io.py -> build\lib.win-amd64-cpython-38\mmcv\fileio
#   copying mmcv\fileio\parse.py -> build\lib.win-amd64-cpython-38\mmcv\fileio
#   copying mmcv\fileio\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\fileio
#   creating build\lib.win-amd64-cpython-38\mmcv\image
#   copying mmcv\image\colorspace.py -> build\lib.win-amd64-cpython-38\mmcv\image
#   copying mmcv\image\geometric.py -> build\lib.win-amd64-cpython-38\mmcv\image
#   copying mmcv\image\io.py -> build\lib.win-amd64-cpython-38\mmcv\image
#   copying mmcv\image\misc.py -> build\lib.win-amd64-cpython-38\mmcv\image
#   copying mmcv\image\photometric.py -> build\lib.win-amd64-cpython-38\mmcv\image
#   copying mmcv\image\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\image
#   creating build\lib.win-amd64-cpython-38\mmcv\onnx
#   copying mmcv\onnx\info.py -> build\lib.win-amd64-cpython-38\mmcv\onnx
#   copying mmcv\onnx\symbolic.py -> build\lib.win-amd64-cpython-38\mmcv\onnx
#   copying mmcv\onnx\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\onnx
#   creating build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\active_rotated_filter.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\assign_score_withk.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\ball_query.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\bbox.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\border_align.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\box_iou_quadri.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\box_iou_rotated.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\carafe.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\cc_attention.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\chamfer_distance.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\contour_expand.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\convex_iou.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\corner_pool.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\correlation.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\deform_conv.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\deform_roi_pool.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\deprecated_wrappers.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\diff_iou_rotated.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\focal_loss.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\furthest_point_sample.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\fused_bias_leakyrelu.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\gather_points.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\group_points.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\info.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\iou3d.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\knn.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\masked_conv.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\merge_cells.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\min_area_polygons.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\modulated_deform_conv.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\multi_scale_deform_attn.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\nms.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\pixel_group.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\points_in_boxes.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\points_in_polygons.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\points_sampler.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\point_sample.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\prroi_pool.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\psa_mask.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\riroi_align_rotated.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\roiaware_pool3d.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\roipoint_pool3d.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\roi_align.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\roi_align_rotated.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\roi_pool.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\rotated_feature_align.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\saconv.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\scatter_points.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sparse_conv.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sparse_functional.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sparse_modules.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sparse_ops.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sparse_pool.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sparse_structure.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\sync_bn.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\three_interpolate.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\three_nn.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\tin_shift.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\upfirdn2d.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\voxelize.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   copying mmcv\ops\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\ops
#   creating build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\collate.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\data_container.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\data_parallel.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\distributed.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\distributed_deprecated.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\registry.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\scatter_gather.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\utils.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\_functions.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   copying mmcv\parallel\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\parallel
#   creating build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\base_module.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\base_runner.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\builder.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\checkpoint.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\default_constructor.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\dist_utils.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\epoch_based_runner.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\fp16_utils.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\iter_based_runner.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\log_buffer.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\priority.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\utils.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   copying mmcv\runner\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\runner
#   creating build\lib.win-amd64-cpython-38\mmcv\tensorrt
#   copying mmcv\tensorrt\init_plugins.py -> build\lib.win-amd64-cpython-38\mmcv\tensorrt
#   copying mmcv\tensorrt\preprocess.py -> build\lib.win-amd64-cpython-38\mmcv\tensorrt
#   copying mmcv\tensorrt\tensorrt_utils.py -> build\lib.win-amd64-cpython-38\mmcv\tensorrt
#   copying mmcv\tensorrt\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\tensorrt
#   creating build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\config.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\device_type.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\env.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\ext_loader.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\hub.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\logging.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\misc.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\parrots_jit.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\parrots_wrapper.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\path.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\progressbar.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\registry.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\seed.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\testing.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\timer.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\torch_ops.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\trace.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\version_utils.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   copying mmcv\utils\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\utils
#   creating build\lib.win-amd64-cpython-38\mmcv\video
#   copying mmcv\video\io.py -> build\lib.win-amd64-cpython-38\mmcv\video
#   copying mmcv\video\optflow.py -> build\lib.win-amd64-cpython-38\mmcv\video
#   copying mmcv\video\processing.py -> build\lib.win-amd64-cpython-38\mmcv\video
#   copying mmcv\video\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\video
#   creating build\lib.win-amd64-cpython-38\mmcv\visualization
#   copying mmcv\visualization\color.py -> build\lib.win-amd64-cpython-38\mmcv\visualization
#   copying mmcv\visualization\image.py -> build\lib.win-amd64-cpython-38\mmcv\visualization
#   copying mmcv\visualization\optflow.py -> build\lib.win-amd64-cpython-38\mmcv\visualization
#   copying mmcv\visualization\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\visualization
#   creating build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\activation.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\context_block.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv2d_adaptive_padding.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv_module.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv_ws.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\depthwise_separable_conv_module.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\drop.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\generalized_attention.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\hsigmoid.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\hswish.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\non_local.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\norm.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\padding.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\plugin.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\registry.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\scale.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\swish.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\transformer.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\upsample.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\wrappers.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\bricks
#   creating build\lib.win-amd64-cpython-38\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\operator.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\search.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\utils.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\rfsearch
#   creating build\lib.win-amd64-cpython-38\mmcv\cnn\utils
#   copying mmcv\cnn\utils\flops_counter.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\utils
#   copying mmcv\cnn\utils\fuse_conv_bn.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\utils
#   copying mmcv\cnn\utils\sync_bn.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\utils
#   copying mmcv\cnn\utils\weight_init.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\utils
#   copying mmcv\cnn\utils\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\cnn\utils
#   creating build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\dataloader.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\hierarchical_data_manager.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\hook_wrapper.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\model_wrapper.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\runner.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\utils.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   copying mmcv\device\ipu\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\device\ipu
#   creating build\lib.win-amd64-cpython-38\mmcv\device\mlu
#   copying mmcv\device\mlu\data_parallel.py -> build\lib.win-amd64-cpython-38\mmcv\device\mlu
#   copying mmcv\device\mlu\distributed.py -> build\lib.win-amd64-cpython-38\mmcv\device\mlu
#   copying mmcv\device\mlu\scatter_gather.py -> build\lib.win-amd64-cpython-38\mmcv\device\mlu
#   copying mmcv\device\mlu\_functions.py -> build\lib.win-amd64-cpython-38\mmcv\device\mlu
#   copying mmcv\device\mlu\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\device\mlu
#   creating build\lib.win-amd64-cpython-38\mmcv\device\mps
#   copying mmcv\device\mps\data_parallel.py -> build\lib.win-amd64-cpython-38\mmcv\device\mps
#   copying mmcv\device\mps\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\device\mps
#   creating build\lib.win-amd64-cpython-38\mmcv\device\npu
#   copying mmcv\device\npu\data_parallel.py -> build\lib.win-amd64-cpython-38\mmcv\device\npu
#   copying mmcv\device\npu\distributed.py -> build\lib.win-amd64-cpython-38\mmcv\device\npu
#   copying mmcv\device\npu\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\device\npu
#   creating build\lib.win-amd64-cpython-38\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\base.py -> build\lib.win-amd64-cpython-38\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\json_handler.py -> build\lib.win-amd64-cpython-38\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\pickle_handler.py -> build\lib.win-amd64-cpython-38\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\yaml_handler.py -> build\lib.win-amd64-cpython-38\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\fileio\handlers
#   creating build\lib.win-amd64-cpython-38\mmcv\onnx\onnx_utils
#   copying mmcv\onnx\onnx_utils\symbolic_helper.py -> build\lib.win-amd64-cpython-38\mmcv\onnx\onnx_utils
#   copying mmcv\onnx\onnx_utils\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\onnx\onnx_utils
#   creating build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\checkpoint.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\closure.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\ema.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\evaluation.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\hook.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\iter_timer.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\lr_updater.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\memory.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\momentum_updater.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\optimizer.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\profiler.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\sampler_seed.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\sync_buffer.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   copying mmcv\runner\hooks\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks
#   creating build\lib.win-amd64-cpython-38\mmcv\runner\optimizer
#   copying mmcv\runner\optimizer\builder.py -> build\lib.win-amd64-cpython-38\mmcv\runner\optimizer
#   copying mmcv\runner\optimizer\default_constructor.py -> build\lib.win-amd64-cpython-38\mmcv\runner\optimizer
#   copying mmcv\runner\optimizer\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\runner\optimizer
#   creating build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\base.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\clearml.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\dvclive.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\mlflow.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\neptune.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\pavi.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\segmind.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\tensorboard.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\text.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\wandb.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\__init__.py -> build\lib.win-amd64-cpython-38\mmcv\runner\hooks\logger
#   running egg_info
#   writing mmcv_full.egg-info\PKG-INFO
#   writing dependency_links to mmcv_full.egg-info\dependency_links.txt
#   writing requirements to mmcv_full.egg-info\requires.txt
#   writing top-level names to mmcv_full.egg-info\top_level.txt
#   reading manifest file 'mmcv_full.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: manifest_maker: MANIFEST.in, line 7: path 'mmcv/ops/csrc/' cannot end with '/'
#
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file 'mmcv_full.egg-info\SOURCES.txt'
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.model_zoo' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.model_zoo' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.model_zoo' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.model_zoo' to be distributed and are
#           already explicitly excluding 'mmcv.model_zoo' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.cuda' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.cuda' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.cuda' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.cuda' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.cuda' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.cuda.spconv' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.cuda.spconv' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.cuda.spconv' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.cuda.spconv' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.cuda.spconv' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.mlu' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.mlu' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.mlu' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.mlu' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.mlu' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.mps' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.mps' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.mps' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.mps' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.mps' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.utils.spconv' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.utils.spconv' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.utils.spconv' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.utils.spconv' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.utils.spconv' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.utils.spconv.spconv' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.utils.spconv.spconv' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.utils.spconv.spconv' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.utils.spconv.spconv' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.utils.spconv.spconv' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.utils.spconv.tensorview' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.utils.spconv.tensorview' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
# ...
#   copying mmcv\ops\csrc\pytorch\cpu\points_in_boxes.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\psamask.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\roi_align.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\roi_align_rotated.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\rotated_feature_align.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\sparse_indice.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\sparse_maxpool.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\sparse_reordering.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\voxelization.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cpu
#   creating build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\active_rotated_filter_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\assign_score_withk_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\ball_query_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\bbox_overlaps_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\bezier_align_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\bias_act_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\border_align_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\box_iou_quadri_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\box_iou_rotated_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\carafe_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\carafe_naive_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\chamfer_distance_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\convex_iou.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\correlation_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\cudabind.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\deform_conv_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\deform_roi_pool_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\diff_iou_rotated_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\filtered_lrelu.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\focal_loss_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\furthest_point_sample_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\fused_bias_leakyrelu_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\fused_spconv_ops_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\gather_points_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\group_points_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\iou3d_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\knn_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\masked_conv2d_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\min_area_polygons.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\modulated_deform_conv_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\ms_deform_attn_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\nms_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\nms_quadri_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\nms_rotated_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\points_in_boxes_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\points_in_polygons_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\prroi_pool_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\psamask_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\riroi_align_rotated_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roi_align_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roi_align_rotated_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roi_pool_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roiaware_pool3d_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roipoint_pool3d_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\rotated_feature_align_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\scatter_points_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_indice.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_maxpool.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_pool_ops_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_reordering.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\spconv_ops_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\stack_ball_query_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\stack_group_points_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sync_bn_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\three_interpolate_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\three_nn_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\tin_shift_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\upfirdn2d_kernel.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\voxelization_cuda.cu -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\cuda
#   creating build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\ball_query_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\bbox_overlaps_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\box_iou_rotated.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\carafe_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\deform_roi_pool_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\focal_loss_sigmoid_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\iou3d_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\masked_conv2d_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\mlu_common_helper.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\mlu_common_helper.h -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\ms_deform_attn_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\nms_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\nms_rotated_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\psamask_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roi_align_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roi_align_rotated_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roi_pool_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roiaware_pool3d_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roipoint_pool3d_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\rotated_feature_align_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\sparse_conv_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\three_nn_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\tin_shift_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\voxelization_mlu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mlu
#   creating build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mps
#   copying mmcv\ops\csrc\pytorch\mps\bbox_overlaps_mps.mm -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\mps
#   creating build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\active_rotated_filter_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\bbox_overlaps_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\deform_roi_pool.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\focal_loss_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\fused_bias_leakyrelu_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\gather_points_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\nms_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\nms_rotated_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\psa_mask_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\roi_align_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\roi_pool_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\voxelization_npu.cpp -> build\lib.win-amd64-cpython-38\mmcv\ops\csrc\pytorch\npu
#   running build_ext
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\torch\utils\cpp_extension.py:383: UserWarning: Error checking compiler version for cl: [WinError 2] 系统找不到指定的文件。
#     warnings.warn(f'Error checking compiler version for {compiler}: {error}')
#   building 'mmcv._ext' extension
#   creating build\temp.win-amd64-cpython-38
#   creating build\temp.win-amd64-cpython-38\Release
#   creating build\temp.win-amd64-cpython-38\Release\mmcv
#   creating build\temp.win-amd64-cpython-38\Release\mmcv\ops
#   creating build\temp.win-amd64-cpython-38\Release\mmcv\ops\csrc
#   creating build\temp.win-amd64-cpython-38\Release\mmcv\ops\csrc\pytorch
#   creating build\temp.win-amd64-cpython-38\Release\mmcv\ops\csrc\pytorch\cpu
#   creating build\temp.win-amd64-cpython-38\Release\mmcv\ops\csrc\pytorch\cuda
#   "C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DMMCV_WITH_CUDA -IC:\Users\storm\AppData\Local\Temp\pip-install-77glodkj\mmcv_aea66895ce6f4798a15b9e33466814af\mmcv\ops\csrc\pytorch -IC:\Users\storm\AppData\Local\Temp\pip-install-77glodkj\mmcv_aea66895ce6f4798a15b9e33466814af\mmcv\ops\csrc\common -IC:\Users\storm\AppData\Local\Temp\pip-install-77glodkj\mmcv_aea66895ce6f4798a15b9e33466814af\mmcv\ops\csrc\common\cuda -ID:\Anaconda3\envs\openmmlab\lib\site-packages\torch\include -ID:\Anaconda3\envs\openmmlab\lib\site-packages\torch\include\torch\csrc\api\include -ID:\Anaconda3\envs\openmmlab\lib\site-packages\torch\include\TH -ID:\Anaconda3\envs\openmmlab\lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.8\include" -ID:\Anaconda3\envs\openmmlab\include -ID:\Anaconda3\envs\openmmlab\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.29.30133\ATLMFC\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.29.30133\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\shared" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\winrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\cppwinrt" /EHsc /Tp./mmcv/ops/csrc/pytorch/cpu\active_rotated_filter.cpp /Fobuild\temp.win-amd64-cpython-38\Release\./mmcv/ops/csrc/pytorch/cpu\active_rotated_filter.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc /std:c++14 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -D_GLIBCXX_USE_CXX11_ABI=0
#   active_rotated_filter.cpp
#   D:\Anaconda3\envs\openmmlab\lib\site-packages\torch\include\c10/util/C++17.h(27): fatal error C1189: #error:  You need C++17 to compile PyTorch
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\Community\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mmcv
# ERROR: Could not build wheels for mmcv, which is required to install pyproject.toml-based projects

# %% [markdown]
# ## 安装其它工具包

# %%
# !pip install opencv-python pillow matplotlib seaborn tqdm pycocotools -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: opencv-python in d:\anaconda3\envs\openmmlab\lib\site-packages (4.8.1.78)
# Requirement already satisfied: pillow in d:\anaconda3\envs\openmmlab\lib\site-packages (10.0.1)
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\openmmlab\lib\site-packages (3.7.4)
# Collecting seaborn
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl (294 kB)
#      ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#      ------------------- ------------------ 153.6/294.6 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 294.6/294.6 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in d:\anaconda3\envs\openmmlab\lib\site-packages (4.65.2)
# Requirement already satisfied: pycocotools in d:\anaconda3\envs\openmmlab\lib\site-packages (2.0.7)
# Requirement already satisfied: numpy>=1.17.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: pandas>=1.2 in d:\anaconda3\envs\openmmlab\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: colorama in d:\anaconda3\envs\openmmlab\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda3\envs\openmmlab\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\envs\openmmlab\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\openmmlab\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0

# %% [markdown]
# ## 下载 MMDetection

# %%
# 删掉原有的 mmdetection 文件夹（如有）
# !rm -rf mmdetection

# %%
# 从 github 上下载最新的 mmdetection 源代码
# !git clone https://github.com/open-mmlab/mmdetection.git -b 3.x
# Out:
# Cloning into 'mmdetection'...

# %%
# 进入主目录
import os
os.chdir('mmdetection')

# %% [markdown]
# ## 安装 MMDetection

# %%
# !pip install -v -e .
# Out:
# Using pip 23.3.1 from D:\Anaconda3\envs\openmmlab\lib\site-packages\pip (python 3.8)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Obtaining file:///E:/openmmlab/MMPose_Tutorials/2023/0524
# ERROR: file:///E:/openmmlab/MMPose_Tutorials/2023/0524 does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# ## 下载预训练模型权重文件和视频素材

# %%
import os

# 创建 checkpoint 文件夹，用于存放预训练模型权重文件
os.mkdir('checkpoint')

# 创建 outputs 文件夹，用于存放预测结果
os.mkdir('outputs')

# 创建 data 文件夹，用于存放图片和视频素材
os.mkdir('data')

# %%
# !pwd
# Out:
# /e/openmmlab/MMPose_Tutorials/2023/0524/mmdetection

# %% [markdown]
# ## 检查安装成功

# %%
# 检查 Pytorch
import torch, torchvision
print('Pytorch 版本', torch.__version__)
print('CUDA 是否可用',torch.cuda.is_available())
# Out:
# Pytorch 版本 2.1.1
# CUDA 是否可用 True

# %%
# 检查 mmcv
import mmcv
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print('MMCV版本', mmcv.__version__)
print('CUDA版本', get_compiling_cuda_version())
print('编译器版本', get_compiler_version())
# Out:
# MMCV版本 2.1.0
# CUDA版本 11.8
# 编译器版本 MSVC 192930148

# %%
# 检查 mmpose
import mmdet
print('mmdetection版本', mmdet.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 检查 mmpose
# ----> 2 import mmdet
#       3 print('mmdetection版本', mmdet.__version__)
#
# ModuleNotFoundError: No module named 'mmdet'

# %% [markdown]
# 没有报错，即证明安装成功。
